# %%
import Augmentor
import os
import glob

from PIL import Image

# %%
root_directory = "images/*"

# %%
folders = []
for f in glob.glob(root_directory):
    if os.path.isdir(f):
        folders.append(os.path.abspath(f))

print("Folders (classes) found: %s " % [os.path.split(x)[1] for x in folders])
# Out:
# Folders (classes) found: ['132', '59', '92', '150', '102', '69', '105', '60', '160', '158', '73', '80', '120', '143', '75', '110', '88', '117', '65', '100', '54', '155', '152', '108', '63', '130', '90', '77', '70', '71', '82', '140']

# %%
pipelines = {}
for folder in folders:
    print("Folder %s:" % (folder))
    pipelines[os.path.split(folder)[1]] = (Augmentor.Pipeline(folder))
    print("\n----------------------------\n")
# Out:
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/132:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/132/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/59:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/59/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/92:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/92/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/150:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/150/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/102:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/102/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/69:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/69/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/105:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/105/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/60:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/60/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/160:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/160/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/158:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/158/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/73:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/73/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/80:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/80/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/120:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/120/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/143:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/143/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/75:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/75/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/110:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/110/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/88:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/88/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/117:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/117/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/65:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/65/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/100:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/100/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/54:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/54/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/155:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/155/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/152:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/152/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/108:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/108/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/63:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/63/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/130:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/130/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/90:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/90/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/77:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/77/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/70:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/70/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/71:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/71/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/82:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/82/output.
# ----------------------------
#
# Folder /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/140:
# Initialised with 1 image(s) found.
# Output directory set to /Users/juanjesusizquierdo/Desktop/ML-DL/AnalogReadDemo/augment/images/140/output.
# ----------------------------

# %%
for p in pipelines.values():
    print("Class %s has %s samples." % (p.augmentor_images[0].class_label, len(p.augmentor_images)))
# Out:
# Class 132 has 1 samples.
# Class 59 has 1 samples.
# Class 92 has 1 samples.
# Class 150 has 1 samples.
# Class 102 has 1 samples.
# Class 69 has 1 samples.
# Class 105 has 1 samples.
# Class 60 has 1 samples.
# Class 160 has 1 samples.
# Class 158 has 1 samples.
# Class 73 has 1 samples.
# Class 80 has 1 samples.
# Class 120 has 1 samples.
# Class 143 has 1 samples.
# Class 75 has 1 samples.
# Class 110 has 1 samples.
# Class 88 has 1 samples.
# Class 117 has 1 samples.
# Class 65 has 1 samples.
# Class 100 has 1 samples.
# Class 54 has 1 samples.
# Class 155 has 1 samples.
# Class 152 has 1 samples.
# Class 108 has 1 samples.
# Class 63 has 1 samples.
# Class 130 has 1 samples.
# Class 90 has 1 samples.
# Class 77 has 1 samples.
# Class 70 has 1 samples.
# Class 71 has 1 samples.
# Class 82 has 1 samples.
# Class 140 has 1 samples.

# %%
for pipeline in pipelines.values():
    pipeline.zoom(probability=0.3, min_factor=1.0, max_factor=1.1)
    pipeline.rotate(probability=0.3, max_left_rotation=5, max_right_rotation=5)
    pipeline.skew_corner(probability=0.3, magnitude=0.1)

# %%
for pipeline in pipelines.values():
    pipeline.sample(1000)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=1601x1285 at 0x136E78490>: 100%|██████████| 1000/1000 [01:12<00:00, 13.76 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1673x1358 at 0x136F0E5D0>: 100%|██████████| 1000/1000 [01:17<00:00, 12.95 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=